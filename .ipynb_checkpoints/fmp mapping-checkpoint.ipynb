# %%
import requests
import json
import os
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()

url = "https://financialmodelingprep.com/stable/search-name"
params = {
    "apikey": os.getenv("FMP_KEY"),
    "exchange": "NASDAQ"
}

# %%
df = pd.read_csv("./data/FMP ticker mapping - not found v1.csv", header=None)
df.columns = ["ticker", "name"]
print(df.head())
# Out:
#        ticker                         name
# 0   600761_CN         Anhui Heli Co., Ltd.
# 1        AMPS              Altus Power Inc
# 2         DOC  Healthpeak Properties, Inc.
# 3  ESSITYB_SE                       Essity
# 4     HEIG_DE        Heidelberg Materials

# %%
def clean(s):
    def fix_mojibake_and_convert_to_ascii(s):
        try:
            # Step 1: Re-encode as bytes using the encoding that misinterpreted UTF-8
            bytes_data = s.encode('latin1')
            # Step 2: Decode properly using UTF-8
            fixed = bytes_data.decode('utf-8')
        except UnicodeEncodeError:
            # If encoding fails, fallback to original
            fixed = s
        except UnicodeDecodeError:
            # If decoding fails, fallback to original
            fixed = s

        # Step 3: Convert to ASCII (remove accents etc.)
        import unicodedata
        ascii_str = unicodedata.normalize('NFKD', fixed).encode('ascii', 'ignore').decode('ascii')
        return ascii_str
    s = fix_mojibake_and_convert_to_ascii(s).lower().replace('.','').replace(',','').replace("'",'')
    s = s.replace(' ltd','').replace(' inc','').replace('nv','').replace(' co', '').replace('-',' ').replace(' sa', '')
    return s.replace(' group', '').replace(' corporation', '').replace(' corp', '')
    


df['clean name'] = df['name'].apply(clean)
print(df.head())
# Out:
#        ticker                         name             clean name
# 0   600761_CN         Anhui Heli Co., Ltd.             anhui heli
# 1        AMPS              Altus Power Inc            altus power
# 2         DOC  Healthpeak Properties, Inc.  healthpeak properties
# 3  ESSITYB_SE                       Essity                 essity
# 4     HEIG_DE        Heidelberg Materials   heidelberg materials

# %%
symbols, names, tickers, fmp_names, exchanges = [], [], [], [], []

counter = 0

for company, name, ticker in zip(df['clean name'], df['name'], df['ticker']):
    print(company)
    
    params['query'], params['exchange'] = company, "NASDAQ"
    r = requests.get(url, params=params)
    try:
        if len(r.json()):
            for res in r.json():
                names.append(name)
                tickers.append(ticker)
                symbols.append(res['symbol'])
                fmp_names.append(res['name'])
                exchanges.append(res['exchange'])
        else:
            params['exchange'] = "NYSE"
            r = requests.get(url, params=params)
            if len(r.json()):
                for res in r.json():
                    names.append(name)
                    tickers.append(ticker)
                    symbols.append(res['symbol'])
                    fmp_names.append(res['name'])
                    exchanges.append(res['exchange'])
            else:
                params['exchange'] = ""
                r = requests.get(url, params=params)
                if len(r.json()) == 0:
                    raise Exception("No data")
                for res in r.json():
                    names.append(name)
                    tickers.append(ticker)
                    symbols.append(res['symbol'])
                    fmp_names.append(res['name'])
                    exchanges.append(res['exchange'])
                
                
    except Exception as e:
        counter += 1
        print(e, counter)
        names.append(company)
        tickers.append(ticker)
        symbols.append('')
        fmp_names.append('')
        exchanges.append('')
#         
    
print(symbols)
# Out:
# anhui heli
# altus power
# healthpeak properties
# essity
# heidelberg materials
# No data 1
# transcontinental
# bioxcel therapeutics
# power grid of india
# No data 2
# itc
# 360 digitech
# No data 3
# upl
# inspired entertainment
# truecar
# emeren
# whitehorse finance
# divis laboratories
# No data 4
# alpineome property trust
# No data 5
# cipla
# cg power & industrial solutions
# No data 6
# telecom plus
# grupo aeroportuario del pacifico
# No data 7
# aedifica
# oric pharmaceuticals
# spruce biosciences
# chow tai fook jewellery
# viracta therapeutics
# nokiarporation
# No data 8
# anglogold ashanti
# nicolet bankshares
# wag
# univestrporation of pennsylvania
# No data 9
# sumitomo mitsui trust
# toho
# toppan holdings
# No data 10
# minebea mitsumi
# cyberagent
# japan post
# colgate palmolive
# No data 11
# unibail rodamco westfield
# No data 12
# nippon express holdings
# orthofix international
# No data 13
# upm kymmene
# No data 14
# marks & spencer
# No data 15
# gladstone landrp
# No data 16
# immunic therapeutics
# No data 17
# liberty formula one
# No data 18
# cto realty growth
# the original barkmpany
# No data 19
# trustco bank ny
# No data 20
# northwesternrporation
# No data 21
# velocity financial
# wise
# raytheon technologiesrporation
# No data 22
# resourcesnnection
# No data 23
# openlane
# tanger factory outlet centers
# No data 24
# citizens
# douglas
# neste
# verallia societe anonyme
# No data 25
# basf
# sichuan kelun biotech biopharmaceutical
# No data 26
# jinko solar
# No data 27
# shanghai united imaging healthcare
# No data 28
# hygon information technology
# No data 29
# jerash (us)
# No data 30
# goodwe technologies
# No data 31
# eastroc beverage
# continental
# mynaric
# chr hansen
# No data 32
# acs actividades denstruccion y servicios
# No data 33
# inner mongolia yili industrial
# galp energia sgps
# No data 34
# nexi
# powszechny zakad ubezpieczen
# No data 35
# super league gaming
# No data 36
# abb
# empyrean technology
# No data 37
# isoftstone information technology
# No data 38
# allianz
# carlsberg
# aena sme
# No data 39
# shenzhen mindray bio medical electronics
# No data 40
# huaneng power international
# akeso
# novonesis
# range intelligentmputing technologympany
# No data 41
# tf1
# No data 42
# byhealth
# No data 43
# sinclair broadcast
# No data 44
# lepu medical technology
# zomato
# gemdale properties and iestmentrporation
# No data 45
# syros pharmaceuticals
# kyverna therapeuticsmmon stock
# No data 46
# biohaven pharmaceutical holdingmpany
# No data 47
# rational
# nel
# bmw
# trent
# allegro
# gerresheimer
# latour
# warehouses de pauw /sa
# No data 48
# ntt data
# prudential
# spirax
# hunting
# sse
# senior
# ambu
# fastighets balder
# No data 49
# ams osram
# No data 50
# kindred
# livzon pharmaceutical
# abeona therapeutics
# neuronetics
# sbb norden
# No data 51
# tingyi cayman islands holding
# No data 52
# l&t services
# No data 53
# zhongsheng holdings
# No data 54
# tencent
# jb chemicals & pharmaceuticals
# No data 55
# barnes
# willscot mobile mini holdingsrp
# No data 56
# south plains financial
# angiodynamics
# volitionrx
# ars pharmaceuticals
# entrada therapeutics
# xperi holdingrporation
# No data 57
# 2seventy bio
# innovex international
# No data 58
# western new england bancorp
# ventyx biosciences
# unity bancorp
# alpha teknova
# vigil neuroscience
# wesbanco
# txo energy partners lp
# No data 59
# x4 pharmaceuticals
# tyra biosciences
# trinseo
# trevi therapeutics
# trueblue
# tactile systems technology
# ew scripps the a
# No data 60
# tscan therapeutics
# relmada therapeutics
# tpimposites
# No data 61
# biodesix
# taskus
# re/max holdings
# rigel pharmaceuticals
# smartrent
# sutro biopharma
# chicago atlantic real estate finance
# sohum
# No data 62
# unity biotechnology
# plymouth industrial reit
# thirdast bancshares
# No data 63
# s&t bancorp
# trivago
# scynexis
# rush enterprises
# q32 bio
# soho house &
# wideopenwest
# rackspace technology
# uniqure
# skywater technology
# pcb bancorp
# personalis
# pra
# proto labs
# pennant
# si bone
# No data 64
# sagimet biosciences
# porch
# purple innovation
# proqr therapeutics
# sera prognostics
# sight sciences
# qcr holdings
# shyft
# shore bancshares
# paymentus holdings
# pdf solutions
# pyxis oncology
# adverum biotechnologies
# cohen & steers
# smartfinancial
# outlook therapeutics
# puma biotechnology
# on24
# dsm firmenich
# No data 65
# edp
# iestor
# No data 66
# gem
# seb
# sca
# lyrporation
# No data 67
# burke & herbert financial services
# No data 68
# m3
# vat
# hcl
# seer
# rani therapeutics holdings
# sharp
# nsk
# resonac holdings
# No data 69
# washington trust bancorp
# ngl energy partners lp
# optinose
# olaplex holdings
# nerdy
# canon
# nexpoint real estate finance
# ooma
# thoughtworks holding
# northfield bancorp
# first western financial
# energy vault holdings
# optimizerxrp
# No data 70
# agc
# nec
# informa
# abrdn
# orange
# nexa resources
# eirirp
# No data 71
# rs
# maxcyte
# schroders
# ses
# tui
# nerdwallet
# shattuck labs
# nextcure
# terna
# next
# mesa laboratories
# modivcare solutions llc
# No data 72
# grainger
# genus
# doma holdings
# mid penn bancorp
# lyra therapeutics
# cranswick
# bp
# affle 3i
# No data 73
# amada
# leap therapeutics
# lindblad expeditions holdings
# dena
# stereotaxis
# microvast holdings
# meridianlink
# neuropace
# lexicon pharmaceuticals
# moleculin biotech
# liberty global
# kalvista pharmaceuticals
# acresmmercial realty
# No data 74
# spie
# smurfit westrock
# oncocyterp
# No data 75
# passage bio
# net power
# kaltura
# pldt
# midwestone financial
# larimar therapeutics
# international money express
# ihs holding
# heartland express
# ibex
# honestmpany
# No data 76
# stellus capital iestrp
# No data 77
# nextdoor holdings
# inozyme pharma
# iheartmedia
# jasper therapeutics
# inovio pharmaceuticals
# tempest therapeutics
# hillevax
# rimini street
# alzchem
# harborone bancorp
# ranger energy services
# monte rosa therapeutics
# granite ridge resources
# glycomimetics
# guaranty bancsharestx
# No data 78
# home bancorp
# grid dynamics holdings
# seb
# global business travel
# fs bancorp
# forge global holdings
# firstvings financial
# No data 79
# compass diversified holdings
# No data 80
# german american bancorp
# ftc solar
# stroeer
# No data 81
# citizensmmunity bancorpwi
# No data 82
# delcath systems
# curis
# cvrx
# enhabit
# corsair gaming
# dare bioscience
# No data 83
# cardiff oncology
# claros mortgage trust
# traeger
# connectone bancorp
# commscope holding
# roche
# aura biosciences
# consensus cloud solutions
# corp america airports
# No data 84
# capital bancorp
# century casinos
# composecure
# coherus biosciences
# cellectar biosciences
# broadwind energy
# No data 85
# doubledown interactive
# brc
# barings bdc
# black diamond therapeutics
# brilliant earth
# actinium pharmaceuticals
# cue biopharma
# senseonics holdings
# rwe
# manitowoc
# nautilus biotechnology
# montauk renewables
# lyell immunopharma
# j jill
# No data 86
# inogen
# health catalyst
# inflarx
# gevo
# erasca
# rapt therapeutics
# fidus iestmentrp
# No data 87
# first citizens bancshares
# eista holdingsrporation
# No data 88
# iss
# enanta pharmaceuticals
# acumen pharmaceuticals
# arteris
# advanced flower capital
# No data 89
# alector
# akoya biosciences
# mayville engineeringmpany
# No data 90
# seres therapeutics
# morgan stanley
# atea pharmaceuticals
# metals acquisitionrp
# No data 91
# imi
# xilio therapeutics
# zura bio
# aeva technologies
# armada hoffler properties
# aclaris therapeutics
# accel entertainment
# cs disco
# y mabs therapeutics
# No data 92
# bain capital specialty finance
# bioatla
# concrete pumping holdings
# backblaze
# avanos medical
# crescent capital bdc
# southern states bancshares
# avientrporation
# No data 93
# idexrporation
# No data 94
# capitol federal financial
# ess tech
# crown crafts
# hbt financial
# great southern bancorp
# garrett motion
# evans bancorp
# cedar fair lp
# No data 95
# kolibri global energy
# nanobiotix
# eve holding
# expensify
# puma
# pandora
# solaris oilfield infrastructure
# p10
# vertex energy
# everest
# duke energyrporation
# No data 96
# omega therapeutics
# vacasa
# bank polski
# myt netherlands parent bv
# No data 97
# orion
# lion electric (the)
# No data 98
# omv aktiengesellschaft
# No data 99
# domo
# oci
# 2u
# hometrust bancshares
# munich re
# No data 100
# mutares
# crossfirst bankshares
# allbirds
# business first bancshares
# propertyguru
# sharecare
# box
# rexel
# gohealth
# singular genomics systems
# marinus pharmaceuticals
# vinci
# fibrogen
# rh
# stem
# rbc bearingsorporated
# No data 101
# angi homeservices
# No data 102
# applied therapeutics
# mediobanca
# mlp
# centerra gold
# culp
# weavemmunications
# No data 103
# voyager therapeutics
# protara therapeutics
# tela bio
# maersk
# No data 104
# upland software
# talkspace
# latham
# postal realty trust
# rezolute
# sixt
# kore holdings
# No data 105
# rapid micro biosystems
# igm biosciences
# first financial northwest
# kerry
# i3 verticals
# first bank (nj)
# No data 106
# chimerix
# cara therapeutics
# custom truck one source
# bcb bancorp
# poseida therapeutics
# signify
# lulus fashion lounge holdings
# No data 107
# century therapeutics
# gain therapeutics
# hydrofarm holdings
# genasys
# fulgent genetics
# full house resorts
# farmers & merchants bancorp
# elevation oncology
# cytek biosciences
# americas car mart
# No data 108
# bionano genomics
# belite bio
# axt
# athira pharma
# kwsat &
# No data 109
# atara biotherapeutics
# asure software
# loandepot
# angel oak mortgage
# aemetis
# amylyx pharmaceuticals
# airsculpt technologies
# bolt biotherapeutics
# american public education
# phx minerals
# akebia therapeutics
# leonardo
# kone
# kingspan
# jeronimo martins
# No data 110
# michelin
# lvmh
# enfusion
# caremax
# chuys holdings
# No data 111
# covenant transportation
# No data 112
# california bancorp
# lumos pharma
# adtheorent holdingmpany
# No data 113
# augmedix
# allovir
# allego
# the aaronsmpany
# No data 114
# volution
# fdj
# No data 115
# future
# excelerate energy
# 8x8
# ehealth
# just eat takeawaycom
# No data 116
# inditex
# No data 117
# equillium
# design therapeutics
# dada nexus
# iac
# gritstone oncology
# No data 118
# fresenius
# enel
# youdao
# axa
# danimer scientific
# elis
# big lots
# beigene
# c&c
# bic
# aadi bioscience
# assura
# richemont
# credit agricole
# metro
# atlaspco
# No data 119
# alten
# aeroports de paris
# jiangsu yanghe distillery
# No data 120
# ['600761.SS', 'AMPS-WT', 'AMPS', 'PEAK', 'DOC', 'RTLPP', 'RTLPO', 'RTL', '', 'TCI', 'BTAI', '', 'BTMWW', 'BTM', 'BTCFX', 'SFIX', 'BMAX', 'IBIT', 'BTF', 'WGMI', 'MAXI', 'BTGD', 'BRRR', 'BTFX', 'PLKI', 'OOSB', 'BITS', 'OOQB', 'ZZZ', '', 'UPLD', 'INSE', 'TRUE', 'SOL', 'WHF', 'WHFBZ', 'WHFCL', '', '', 'SCPL', '', 'TEP.L', '', 'AEDFF', 'AED.BR', 'ORIC', 'SPRB', 'CJEWY', 'CJEWF', '1929.HK', 'VIRX', '', 'AU', 'NCBS', 'PETWW', 'PET', 'NBEV', '', 'SUTNY', 'CMTDF', '8309.T', 'ATHM', '', 'MNBEY', 'MNBEF', 'CYGIY', 'CYAGF', '4751.T', 'JPSTF', 'JPPTY', '7182.T', 'JPPHY', 'JPHLF', '6178.T', 'JPPIF', '7181.T', '', '', '9147.T', '', '', '', '', '', '', 'CTO-PA', 'CTO', '', '', '', 'VEL', 'WKEY', 'FINW', 'AETH', 'BTOP', 'EWTX', 'MKTWW', 'MKTW', '', '', 'KAR', '', 'CZNC', 'CZWI', 'CZFS', 'FCNCP', 'FCNCO', 'FCNCA', 'DOUG', 'DEI', 'PLOW', 'SDHC', 'SNES', '', 'BFFAF', 'BF', 'BAS.SW', 'BASFY', 'BAS.F', 'BAS.DE', 'BASA.DE', 'BASF.NS', 'BASF.BO', '', '', '', '', '', '', '605499.SS', 'PCBK', 'MYNA', '', '', '600887.SS', '', 'SCYX', '', '', 'LHYVX', 'LACFX', 'LBNOX', 'LBNVX', 'LMIYX', 'LLDYX', 'LOLDX', 'LCRDX', 'LDLVX', 'LMVYX', 'LDCVX', 'LISSX', 'LFHIX', 'LUBAX', 'LADVX', '', '', 'RCGTX', 'CARL-B.CO', 'CARL-A.CO', 'CABJF', 'CABHF', 'CABGY', '2836.KL', '', '', 'HNP', '9926.HK', 'NSISBC.XD', '', '', '', '', '300003.SZ', 'ZOMATO.NS', 'ZOMATO.BO', '', 'SYRS', '', '', 'HSUTX', 'GNLX', 'KRNLW', 'KRNLU', 'KRNL', 'CISO', 'NEFJX', 'NEJYX', 'BMW.BO', 'SMRT', 'ALGM', 'GXI.SW', 'GXI.DE', 'GRRMF', 'LATO-B.ST', 'IVTBF', '', 'NTTDF', 'NTDTY', '9613.T', '3850.T', 'PBIP', 'SPXSY', 'SPXSF', 'SPX.L', 'HBANP', 'HBANO', 'HBANN', 'HBANM', 'HBANL', 'HBAN', 'ESND', 'ASST', 'ESN', 'ASRT', 'OSN', 'ASMB', 'BSET', 'OMEX', 'BENEW', 'BENEU', 'BENER', 'BENE', 'SSGAX', 'SEAIX', 'SXMAX', 'SKTAX', 'SISAX', 'SGOAX', 'RAAQ', 'RAAQU', 'BARIX', 'BARUX', 'RMSG', 'BARAX', 'MDIV', 'MICGX', 'RYRHX', 'WABF', 'GABAX', 'WBND', 'CLMS', 'DAAQ', 'SMMOX', 'SHMMX', 'DAAQU', 'WINC', 'WACPX', 'WAPSX', 'SMMCX', 'ARMZX', 'FTANX', 'FSANX', 'FFANX', 'FASMX', 'FASIX', 'IRACX', 'FFTMX', 'FEYTX', 'FEYIX', 'FEYCX', 'FASGX', 'FAMRX', 'FAASX', 'BRMKX', 'BRMAX', 'BSMAX', 'MDSKX', 'MASKX', 'AMCA', 'USLB', 'GLDI', 'SLVO', 'USOI', 'VTWO', 'VTHR', 'VONE', 'VTWV', 'VONV', 'VTWG', 'VONG', 'RDTY', 'POSKX', 'POGRX', 'POAGX', 'VLAAX', 'VLAIX', 'NRIFX', 'RALOX', 'NRIIX', 'NRICX', 'NRIAX', 'SAMG', 'PAIAX', 'BTBFX', 'LOGBX', 'DAM', 'ITTIX', 'ITTAX', 'IHAYX', 'HAFCX', 'ETNMX', 'ETIMX', 'ASET', 'SFAAX', 'PJLXX', 'FTREX', 'DLMOX', 'FTASX', 'FEYAX', 'FCASX', 'SNRHW', 'SNRHU', 'SNRH', 'XPRTX', 'FVE', 'FTSL', 'SNLN', 'COWNL', 'JMPNL', 'FOSLL', 'JMPNZ', 'CNFRL', 'ARBKL', 'HROWL', 'HROWM', 'SWKHL', 'RILYZ', 'RILYT', 'RILYK', 'RILYG', 'NEWTI', 'NEWTG', 'ABLLL', 'SNCRL', 'ATLCZ', 'ATLCL', 'GREEL', 'RMBS', '', '', 'KIN', 'LVZPF', '1513.HK', '000513.SZ', 'ABEO', 'STIM', '', '', '', '', 'TME', '', 'BNED', '', 'SPFI', 'ANGO', 'VNRX', 'SPRY', 'TRDA', '', 'TSVTV', 'TSVT', '', 'WNEB', 'VTYX', 'UNTY', 'UCBA', 'CZWI', 'NECB', 'CVCY', 'TKNO', 'VIGL', 'WSBCP', 'WSBC', '', 'XFOR', 'TYRA', 'TSE', 'TRVI', 'TBI', 'TCMD', '', 'TCRX', 'RLMD', '', 'BDSX', 'TASK', 'RMAX', 'RIGL', 'SMRT', 'STRO', 'REFI', '', 'UBX', 'PLYM', '', 'STBA', 'TRVG', 'SCYX', 'RUSHB', 'RUSHA', 'QTTB', 'SHCO', 'WOW', 'RXT', 'QURE', 'SKYT', 'PCB', 'PSNL', 'PRAA', 'MVIIX', 'PROP', 'PRAX', 'MMDEX', 'EPRX', 'LEXI', 'MZCSX', 'PRLB', 'PNNTG', 'PNTG', '', 'SGMT', 'PRCH', 'PRPL', 'PRQR', 'SERA', 'SGHT', 'QCRH', 'SHYF', 'SHBI', 'PAY', 'PDFS', 'PYXS', 'ADVM', 'CSRSX', 'CPXIX', 'CSUAX', 'CSSPX', 'CSJZX', 'CSRIX', 'IRFAX', 'CPXAX', 'SMBK', 'OTLK', 'OTLKW', 'PBYI', 'ONTF', '', 'MEDP', '', 'GMTX', 'ENCPW', 'ENCPU', 'ENCP', 'BNAIW', 'BNAI', 'MTSL', 'RMCOW', 'RMCO', 'CLMS', 'BCSIX', 'BCSSX', 'BCSVX', 'BCSFX', 'RHLD', 'GCMG', 'ICMB', 'SAMG', 'RHLDV', 'BTBFX', 'IWTR', 'HCAI', 'JCRAX', 'IPM', 'PHCF', 'PHAS', 'SCSC', 'STAI', 'ZS', 'ESCA', 'TCRX', 'CACB', 'THCBW', 'THCBU', 'THCB', 'CSCD', 'THCAW', 'THCAU', 'THCA', 'CCAIW', 'CCAIU', 'CCAI', 'ERAS', 'TRNS', 'SCLEW', 'SCLEU', 'SCLE', 'DSGX', '', '', 'MBA ...

# %%
df = pd.DataFrame({
    'Ticker' : tickers,
    'Name' : names,
    'FMP name': fmp_names,
    'FMP symbol' : symbols,
    'Exchange' : exchanges
})
df.to_csv(r'data/FMP extracted4.csv', index=False)

# %%
print(counter)
# Out:
# 396
