# %%
import requests
import os
from dotenv import load_dotenv
import pandas as pd
import json
import time

load_dotenv()

url = "https://api.newsedge.moodysanalytics.com/news"
headers = {
    "Authorization": os.getenv("TOKEN"),
    "accept": "application/json"
}

params = {
    "facets_stats_top": 1,
    "page_size": 25,
    "page_number": 1,
    "enable_stemming": "false",
    "enable_highlighting": "false",
    "query" : "Zomato"
}
r = requests.get(url=url, headers=headers, params=params)

print(r)
# Out:
# <Response [200]>

# %%
f = pd.read_csv("./data/remaining moody.csv")
# Out:
# None

# %%
print(f)
# Out:
#     db_ticker                                     db_name  orbis_id  id  name  \
# 0         NXT                                  nextracker       NaN NaN   NaN
# 1         CSR                                 centerspace       NaN NaN   NaN
# 2         CRL    charles river laboratories international       NaN NaN   NaN
# 3      BLX_PA  banco latinoamericano de comercio exterior       NaN NaN   NaN
# 4     TCLA_CA                            transcontinental       NaN NaN   NaN
# ..        ...                                         ...       ...  ..   ...
# 407       SUM                            summit materials       NaN NaN   NaN
# 408       SGH                       smart global holdings       NaN NaN   NaN
# 409       OLK                     olink holding ab (publ)       NaN NaN   NaN
# 410       OEC                 orion engineered carbons sa       NaN NaN   NaN
# 411        BG                                       bunge       NaN NaN   NaN
#
#      symbol
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 407     NaN
# 408     NaN
# 409     NaN
# 410     NaN
# 411     NaN
#
# [412 rows x 6 columns]

# %%
data = {'db_ticker' : [], 'db_name':[], 'name':[],'orbis_id':[], 'id':[], 'symbol':[] }
# print(json.dumps(r.json()['data']['stories'][0]['organizations'], indent=2))

for db_ticker, db_name in zip(f['db_ticker'], f['db_name']):
    params["query"] = '"' + db_name + '"'
    r = requests.get(url=url, headers=headers, params=params)
    
    print(db_name)
    
    print(r.status_code)
    if(r.status_code != 200):
        print(r.reason, r.text)
        print(db_name)
        print()
        continue
    try:
        orgs = r.json()['data']['stories'][0]['organizations']
    except (KeyError, IndexError) as e:
        print('e1', e, db_ticker)
        continue
    
    print(json.dumps(orgs, indent=2))
    for data_value in orgs:
        try:
            data["db_ticker"].append(db_ticker)
            data["db_name"].append(db_name)
            data["name"].append(data_value['name'])
            data["orbis_id"].append(data_value['orbis_id'])
            data["id"].append(data_value['id'])
            try:
                data["symbol"].append(data_value['securities'][0]['symbol'])
            except IndexError:
                data["symbol"].append("")
        except (KeyError, IndexError) as e:
            print('e2', e, data_value)
    time.sleep(0.3)
    
print(*data, sep='\n')
# Out:
# nextracker
# 200
# [
#   {
#     "orbis_id": "221662672",
#     "other_ids": [],
#     "ult_parent_id": "1641443999",
#     "name": "Nextracker Inc.",
#     "id": "2769295863",
#     "necoid": "643812232",
#     "is_ult_parent": false,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "NXT",
#         "mic": "XNAS",
#         "context": "cik",
#         "exchange_symbol": "NASDAQ-NMS:NXT",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "006532750",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Flex Ltd.",
#     "id": "1641443999",
#     "necoid": "9844",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "FLEX",
#         "mic": "XNAS",
#         "context": "cik",
#         "exchange_symbol": "NASDAQ-NMS:FLEX",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# centerspace
# 200
# [
#   {
#     "orbis_id": "000498271",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Centerspace",
#     "id": "0301265659",
#     "necoid": "165477",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "CSR",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CSR",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# charles river laboratories international
# 200
# [
#   {
#     "orbis_id": "499663068",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Ginkgo Bioworks Holdings Inc.",
#     "id": "5011420491",
#     "necoid": "8420491",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "DNA",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:DNA",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000664810",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Charles River Laboratories International Inc.",
#     "id": "4046448084",
#     "necoid": "4968",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "CRL",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CRL",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# banco latinoamericano de comercio exterior
# 200
# [
#   {
#     "orbis_id": "009065363",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Banco Latinoamericano De Comercio Exterior SA",
#     "id": "1825425477",
#     "necoid": "2678",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "BLX",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:BLX",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "313188082",
#     "other_ids": [],
#     "ult_parent_id": "0618954438",
#     "name": "Fitch Group Inc.",
#     "id": "1942178792",
#     "necoid": "1953178792",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# transcontinental
# 200
# [
#   {
#     "orbis_id": "000471732",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "American Airlines Group Inc.",
#     "id": "1360175248",
#     "necoid": "1371175248",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "AAL",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:AAL",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# cna financial corporation
# 200
# [
#   {
#     "orbis_id": "319461897",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Zurich North America Inc.",
#     "id": "1764373553",
#     "necoid": "1775373553",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "315848521",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Benefitmall Inc.",
#     "id": "2802614099",
#     "necoid": "172070",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000093167",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Duck Creek Technologies Inc.",
#     "id": "5011415216",
#     "necoid": "8415216",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "510650193",
#     "other_ids": [],
#     "ult_parent_id": "3225610827",
#     "name": "Marsh & McLennan Agency LLC",
#     "id": "1229470815",
#     "necoid": "1240470815",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000287147",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Marsh & McLennan Cos. Inc.",
#     "id": "3225610827",
#     "necoid": "16620",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "MMC",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:MMC",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "050090764",
#     "other_ids": [],
#     "ult_parent_id": "1942178792",
#     "name": "Fitch Ratings Inc.",
#     "id": "2488945306",
#     "necoid": "363461675",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000972381",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Everest Group Ltd.",
#     "id": "2029907613",
#     "necoid": "2040907613",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "RE",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:RE",
#         "exchange": "NYSE",
#         "type": "SYNONYM"
#       },
#       {
#         "symbol": "EG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:EG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001704936",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Principal Financial Group Inc.",
#     "id": "3319271170",
#     "necoid": "1193787539",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "PFG",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:PFG",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000667857",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Metlife Inc.",
#     "id": "4203067829",
#     "necoid": "17229",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "MET",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:MET",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000479957",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Arthur J. Gallagher & Co.",
#     "id": "3984302065",
#     "necoid": "1858818434",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "AJG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:AJG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Xavier University",
#     "id": "0118231562",
#     "necoid": "5672370",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000972341",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Allstate Corp.",
#     "id": "2616870500",
#     "necoid": "1001",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ALL",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:ALL",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000298601",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "American International Group Inc.",
#     "id": "0893120575",
#     "necoid": "904120575",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "AIG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:AIG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000361802",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Cameco Corp.",
#     "id": "4241153383",
#     "necoid": "2115669752",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CINF",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:CINF",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000301891",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Globe Life Inc.",
#     "id": "0489853849",
#     "necoid": "500853849",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GL",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:GL",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001001634",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Loews Corp.",
#     "id": "1301904774",
#     "necoid": "1312904774",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "L",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:L",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "079151123",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Marsh McLennan",
#     "id": "0184938450",
#     "necoid": "195938450",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "008732852",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Prudential Financial Inc.",
#     "id": "0850645888",
#     "necoid": "21426",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "PRU",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:PRU",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001879100",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Hartford Insurance Group Inc.",
#     "id": "5011413847",
#     "necoid": "8413847",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "HIG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:HIG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001832635",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Travelers Companies Inc.",
#     "id": "4169130196",
#     "necoid": "2043646565",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "TRV",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:TRV",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "008148236",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "W.R. Berkley Corp.",
#     "id": "1297211162",
#     "necoid": "1308211162",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "WRB",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:WRB",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Dominican University of California",
#     "id": "2457959858",
#     "necoid": "5316567",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "022069974",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Santa Clara University",
#     "id": "0637078319",
#     "necoid": "5654579",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Drake University",
#     "id": "2692201557",
#     "necoid": "5618059",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "020775322",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The University of Iowa",
#     "id": "4153355700",
#     "necoid": "2027872069",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000000420",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Berkshire Hathaway Inc.",
#     "id": "2878778268",
#     "necoid": "3166",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "BRK.B",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:BRK.B",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000669792",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "UnitedHealth Group Inc.",
#     "id": "1497911768",
#     "necoid": "1508911768",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "UNH",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:UNH",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "012000256",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Sears Holdings Corp.",
#     "id": "1510402958",
#     "necoid": "292283",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000511040",
#     "other_ids": [],
#     "ult_parent_id": "2985297848",
#     "name": "Protection Services Inc.",
#     "id": "0059803352",
#     "necoid": "3494245",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "014112783",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Corebridge Financial Inc.",
#     "id": "5011425098",
#     "necoid": "8425098",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CRBG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CRBG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "367386990",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Willis Towers Watson Public Ltd. Co.",
#     "id": "4152067604",
#     "necoid": "2026583973",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "WTW",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:WTW",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "314667139",
#     "other_ids": [],
#     "ult_parent_id": "3733429146",
#     "name": "Eastern Insurance Group LLC",
#     "id": "1150052435",
#     "necoid": "1161052435",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "415238720",
#     "other_ids": [],
#     "ult_parent_id": "3400318202",
#     "name": "My Plan Manager Group Pty Ltd.",
#     "id": "0309120630",
#     "necoid": "320120630",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "059284040",
#     "other_ids": [],
#     "ult_parent_id": "4241153383",
#     "name": "Cincinnati Insurance Co.",
#     "id": "0315777371",
#     "necoid": "181460",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000508353",
#     "other_ids": [],
#     "ult_parent_id": "4241153383",
#     "name": "The Cincinnati Casualty Co.",
#     "id": "1666976835",
#     "necoid": "213680",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006502799",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "A.M. Best Co. Inc.",
#     "id": "0879856307",
#     "necoid": "5537076",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000289067",
#     "other_ids": [],
#     "ult_parent_id": "1301904774",
#     "name": "CNA Financial Corp.",
#     "id": "0954395873",
#     "necoid": "5680",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CNA",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CNA",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001642789",
#     "other_ids": [],
#     "ult_parent_id": "1301904774",
#     "name": "Diamond Offshore Drilling Inc.",
#     "id": "3848478116",
#     "necoid": "1722994485",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "014169266",
#     "other_ids": [],
#     "ult_parent_id": "1301904774",
#     "name": "Boardwalk Pipeline Partners LP",
#     "id": "1434421836",
#     "necoid": "3103264",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000702112",
#     "other_ids": [],
#     "ult_parent_id": "1301904774",
#     "name": "Loews Hotels Holding Corp.",
#     "id": "0644213696",
#     "necoid": "655213696",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Altium Packaging LP",
#     "id": "3142931417",
#     "necoid": "5830426",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "008240220",
#     "other_ids": [],
#     "ult_parent_id": "1301904774",
#     "name": "Boardwalk Pipelines LP",
#     "id": "1791052187",
#     "necoid": "2959576",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006470941",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Arlington Hotel Co. Inc.",
#     "id": "1484402752",
#     "necoid": "5342508",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000304707",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Lincoln National Corp.",
#     "id": "0178858996",
#     "necoid": "15988",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "LNC",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:LNC",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "220622172",
#     "other_ids": [],
#     "ult_parent_id": "0178858996",
#     "name": "Lincoln Financial Group LLC",
#     "id": "3684939922",
#     "necoid": "1559456291",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "0178858996",
#     "name": "The Lincoln National Life Insurance Co.",
#     "id": "3329535568",
#     "necoid": "1204051937",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006369089",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Workplace Solutions Inc.",
#     "id": "5020491493",
#     "necoid": "758524231",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "007255756",
#     "other_ids": [],
#     "ult_parent_id": "3912277459",
#     "name": "Retirement Plan Services LLC",
#     "id": "5020503508",
#     "necoid": "758536246",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001348972",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "NBT Bancorp. Inc.",
#     "id": "3912277459",
#     "necoid": "18369",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "NBTB",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:NBTB",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "007129979",
#     "other_ids": [],
#     "ult_parent_id": "3225610827",
#     "name": "Guy Carpenter & Co. Ltd.",
#     "id": "1479200639",
#     "necoid": "1490200639",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000044366",
#     "other_ids": [],
#     "ult_parent_id": "4203067829",
#     "name": "Metropolitan Life Insurance Co.",
#     "id": "5020097503",
#     "necoid": "758130241",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000312465",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Progressive Corp.",
#     "id": "5011413867",
#     "necoid": "8413867",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "PGR",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:PGR",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000432409",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "AARP",
#     "id": "1960028374",
#     "necoid": "5536256",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000043608",
#     "other_ids": [],
#     "ult_parent_id": "3319271170",
#     "name": "Principal Life Insurance Co.",
#     "id": "1607712598",
#     "necoid": "5191409",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "030509521",
#     "other_ids": [],
#     "ult_parent_id": "4239790976",
#     "name": "W & R Holdings Ltd.",
#     "id": "1825587038",
#     "necoid": "1836587038",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# the clorox company
# 200
# [
#   {
#     "orbis_id": "006741191",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Clorox Co.",
#     "id": "0287132874",
#     "necoid": "298132874",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CLX",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CLX",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "207233547",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Kansas State University",
#     "id": "1838814161",
#     "necoid": "5313877",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# core laboratories nv
# 200
# e1 list index out of range CLB
# tradeweb markets
# 200
# [
#   {
#     "orbis_id": "407617405",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Tradeweb Markets Inc.",
#     "id": "5011411371",
#     "necoid": "8411371",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "TW",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:TW",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "541894516",
#     "other_ids": [],
#     "ult_parent_id": "2481206975",
#     "name": "Deloitte & Touche LLP (United States)",
#     "id": "3306984787",
#     "necoid": "3496811",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# albemarle corporation
# 200
# [
#   {
#     "orbis_id": "001750706",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Albemarle Corp.",
#     "id": "2379488039",
#     "necoid": "254004408",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "ALB",
#         "mic": "XNYS",
#         "context": "mapper",
#         "exchange_symbol": "NYSE:ALB",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# cyberark software
# 200
# [
#   {
#     "orbis_id": "049996073",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Alpha Modus Holdings Inc.",
#     "id": "5011420182",
#     "necoid": "8420182",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "AMOD",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:AMOD",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Wakefern Food Corp.",
#     "id": "2169556247",
#     "necoid": "1887710",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "202580889",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Albertsons Companies Inc.",
#     "id": "5011414821",
#     "necoid": "8414821",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ACI",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:ACI",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "382348356",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Alamo Drafthouse Cinemas LLC",
#     "id": "6000175308",
#     "necoid": "6175308",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001691505",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Baskin Robbins",
#     "id": "5020470397",
#     "necoid": "758503135",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000170796",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Best Buy Co. Inc.",
#     "id": "3232970359",
#     "necoid": "1107486728",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "BBY",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:BBY",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000050539",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Nordstrom Inc.",
#     "id": "0465965194",
#     "necoid": "19123",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "JWN",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:JWN",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "205416198",
#     "other_ids": [],
#     "ult_parent_id": "3386412004",
#     "name": "Walgreen Co.",
#     "id": "3455891238",
#     "necoid": "1330407607",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "049986723",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Walmart Inc.",
#     "id": "3048467309",
#     "necoid": "28682",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "WMT",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:WMT",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       },
#       {
#         "symbol": "WMT",
#         "mic": "NEOE",
#         "context": "extractor",
#         "exchange_symbol": "NEO:WMT",
#         "exchange": "NEO",
#         "type": "SYNONYM"
#       }
#     ]
#   },
#   {
#     "orbis_id": "075113398",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Groupon Inc.",
#     "id": "1808319061",
#     "necoid": "1819319061",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GRPN",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:GRPN",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "076503173",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Living Spaces Furniture LLC",
#     "id": "2736522985",
#     "necoid": "5392993",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "008320646",
#     "other_ids": [],
#     "ult_parent_id": "2895615606",
#     "name": "Gillam",
#     "id": "1883462454",
#     "necoid": "1894462454",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000003096",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Frequency Electronics Inc.",
#     "id": "2895615606",
#     "necoid": "10124",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "FEIM",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:FEIM",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "219086885",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "American Giant Inc.",
#     "id": "5020362269",
#     "necoid": "758395007",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006373540",
#     "other_ids": [],
#     "ult_parent_id": "2786944818",
#     "name": "CyberArk Software Ltd.",
#     "id": "2786944818",
#     "necoid": "661461187",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CYBR",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:CYBR",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "039652014",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Backcountry.com LLC",
#     "id": "3954186517",
#     "necoid": "1828702886",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000464220",
#     "other_ids": [],
#     "ult_parent_id": "1264679256",
#     "name": "Benefit Cosmetics LLC",
#     "id": "2550920927",
#     "necoid": "3734239",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "003882400",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "LVMH Moet Hennessy Louis Vuitton SE",
#     "id": "1264679256",
#     "necoid": "16263",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "MC",
#         "mic": "XPAR",
#         "context": "extractor",
#         "exchange_symbol": "EuronextParis:MC",
#         "exchange": "EuronextParis",
#         "type": "REFERENCE"
#       },
#       {
#         "symbol": "LVMUY",
#         "mic": "OTCM",
#         "context": "extractor",
#         "exchange_symbol": "OTC-PINK:LVMUY",
#         "exchange": "OTC-PINK",
#         "type": "SYNONYM"
#       }
#     ]
#   },
#   {
#     "orbis_id": "051175742",
#     "other_ids": [],
#     "ult_parent_id": "3253680726",
#     "name": "Comerica Bank",
#     "id": "0318737313",
#     "necoid": "329737313",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "318217944",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Comerica Inc.",
#     "id": "3253680726",
#     "necoid": "1128197095",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CMA",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CMA",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000476927",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Computer Aid Inc.",
#     "id": "3463577517",
#     "necoid": "3468049",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000090841",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Sporting Goods Inc.",
#     "id": "5020380364",
#     "necoid": "758413102",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "169036956",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Del Taco Restaurants Inc.",
#     "id": "3667046486",
#     "necoid": "1541562855",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "169977810",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Delta Air Lines, Inc.",
#     "id": "0939301067",
#     "necoid": "7292",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "DAL",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:DAL",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "200299951",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Digital Federal Credit Union",
#     "id": "2159385191",
#     "necoid": "5209714",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001869983",
#     "other_ids": [],
#     "ult_parent_id": "1013461158",
#     "name": "Dominion Dental Services Inc.",
#     "id": "4211562965",
#     "necoid": "5618041",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000568474",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "First Technology Federal Credit Union",
#     "id": "2037781291",
#     "necoid": "5209594",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "199789650",
#     "other_ids": [],
#     "ult_parent_id": "2037781291",
#     "name": "First Tech Federal Credit Union",
#     "id": "3296873965",
#     "necoid": "5206993",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "372678047",
#     "other_ids": [],
#     "ult_parent_id": "3303995376",
#     "name": "General Dynamics Information Technology Inc.",
#     "id": "1160000206",
#     "necoid": "1171000206",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000003603",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "General Dynamics Corp.",
#     "id": "3303995376",
#     "necoid": "10587",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GD",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:GD",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "352396680",
#     "other_ids": [],
#     "ult_parent_id": "3097170909",
#     "name": "General Nutrition Corp.",
#     "id": "0589043525",
#     "necoid": "600043525",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "171921639",
#     "other_ids": [],
#     "ult_parent_id": "5011377015",
#     "name": "GrubHub Inc.",
#     "id": "5011377015",
#     "necoid": "8377015",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "509885428",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Likewize Corp.",
#     "id": "5020243369",
#     "necoid": "758276107",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000043779",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Massachusetts Mutual Life Insurance Co.",
#     "id": "4204385838",
#     "necoid": "2078902207",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000017176",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The American Automobile Association Inc.",
#     "id": "2311567572",
#     "necoid": "3576461",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "4044963814",
#     "name": "Cke Restaurants Holdings Inc.",
#     "id": "2158274316",
#     "necoid": "32790685",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000301891",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Globe Life Inc.",
#     "id": "0489853849",
#     "necoid": "500853849",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GL",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:GL",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000028620",
#     "other_ids": [],
#     "ult_parent_id": "1925023209",
#     "name": "Guaranty Bank & Trust N.A.",
#     "id": "5020097430",
#     "necoid": "758130168",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "011149850",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Guaranty Bancshares Inc. (TX)",
#     "id": "1925023209",
#     "necoid": "11460",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GNTY",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:GNTY",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "172644507",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Higginbotham Insurance Group Inc.",
#     "id": "2658569492",
#     "necoid": "533085861",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000634930",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Hotchkiss Insurance Agency LLC",
#     "id": "3599298952",
#     "necoid": "5211484",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000436041",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Gulf States Financial Services Inc.",
#     "id": "1096372867",
#     "necoid": "5207008",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "217207532",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Interflex Payments LLC",
#     "id": "0358139458",
#     "necoid": "369139458",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "257919104",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "La Familia Agency LLC",
#     "id": "1817769392",
#     "necoid": "1828769392",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "343202425",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Payroll Inc.",
#     "id": "5011418657",
#     "necoid": "8418657",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000635522",
#     "other_ids": [],
#     "ult_parent_id": "3819152725",
#     "name": "Lone Star National Bank",
#     "id": "0226360705",
#     "necoid": "5212971",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000637903",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Costco Wholesale Corp.",
#     "id": "0548237919",
#     "necoid": "559237919",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "COST",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:COST",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "025024069",
#     "other_ids": [],
#     "ult_parent_id": "3037557088",
#     "name": "Cvs Pharmacy",
#     "id": "5021355217",
#     "necoid": "759387955",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000003247",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "CVS Health Corp.",
#     "id": "3037557088",
#     "necoid": "6746",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CVS",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CVS",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# agilon health
# 200
# [
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Mass General Brigham Inc.",
#     "id": "3136888587",
#     "necoid": "5289641",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": []
#   },
#   {
#     "orbis_id": "207370272",
#     "other_ids": [],
#     "ult_parent_id": "0788012978",
#     "name": "Harvard Medical School",
#     "id": "3595432114",
#     "necoid": "5312996",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# metallus
# 200
# [
#   {
#     "orbis_id": "510651362",
#     "other_ids": [],
#     "ult_parent_id": "5010018137",
#     "name": "Lyondellbasell Advanced Polymers Inc.",
#     "id": "0425511983",
#     "necoid": "436511983",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "SLMNP",
#         "mic": "OTCM",
#         "context": "extractor",
#         "exchange_symbol": "OTC-PINK:SLMNP",
#         "exchange": "OTC-PINK",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "075072297",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "LyondellBasell Industries NV",
#     "id": "5010018137",
#     "necoid": "7018137",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "LYB",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:LYB",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001662176",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Materion Corp.",
#     "id": "2566822182",
#     "necoid": "441338551",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "MTRN",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:MTRN",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000025712",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Timken Co.",
#     "id": "0985968602",
#     "necoid": "26725",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "TKR",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:TKR",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# cullen/frost bankers
# 200
# [
#   {
#     "orbis_id": "001643361",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Federal Agricultural Mortgage Corp.",
#     "id": "1530032560",
#     "necoid": "1541032560",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "AGM",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:AGM",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000385418",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Cullen Frost Bankers Inc.",
#     "id": "1632672466",
#     "necoid": "1643672466",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "CFR",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CFR",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "222096950",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Zacks Investment Research Inc.",
#     "id": "0575874126",
#     "necoid": "2617069",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "108501007",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Horace Mann Educators Corp.",
#     "id": "3719602222",
#     "necoid": "12485",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "HMN",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:HMN",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# certara
# 200
# [
#   {
#     "orbis_id": "493993091",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Certara Inc.",
#     "id": "5011416513",
#     "necoid": "8416513",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "CERT",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:CERT",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# sunpower corporation
# 200
# [
#   {
#     "orbis_id": "299967077",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Solar Energy Industries Association",
#     "id": "0360301735",
#     "necoid": "371301735",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "122493297",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Power Engineering JSC",
#     "id": "5011420792",
#     "necoid": "8420792",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "PEC",
#         "mic": "HSTC",
#         "context": "extractor",
#         "exchange_symbol": "Hanoi:PEC",
#         "exchange": "Hanoi",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "005600703",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Equinor ASA",
#     "id": "5010025072",
#     "necoid": "7025072",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "EQNR",
#         "mic": "XOSL",
#         "context": "extractor",
#         "exchange_symbol": "Oslo:EQNR",
#         "exchange": "Oslo",
#         "type": "REFERENCE"
#       },
#       {
#         "symbol": "EQNR",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:EQNR",
#         "exchange": "NYSE",
#         "type": "SYNONYM"
#       }
#     ]
#   },
#   {
#     "orbis_id": "363476326",
#     "other_ids": [],
#     "ult_parent_id": "1309279597",
#     "name": "Bureau of Ocean Energy Management",
#     "id": "0865672853",
#     "necoid": "876672853",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "216461544",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Array Technologies Inc.",
#     "id": "5011415807",
#     "necoid": "8415807",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ARRY",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:ARRY",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "148401620",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "ACWA Power Co.",
#     "id": "3552430078",
#     "necoid": "1426946447",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "2082",
#         "mic": "XSAU",
#         "context": "extractor",
#         "exchange_symbol": "SaudiArabia:2082",
#         "exchange": "SaudiArabia",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "027693289",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Enphase Energy Inc.",
#     "id": "5011423010",
#     "necoid": "8423010",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ENPH",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:ENPH",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "027787458",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Ascent Solar Technologies Inc.",
#     "id": "1311963543",
#     "necoid": "1322963543",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ASTI",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:ASTI",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "012935729",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Alto Ingredients Inc.",
#     "id": "4022542682",
#     "necoid": "1897059051",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ALTO",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:ALTO",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "006739860",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Ballard Power Systems Inc.",
#     "id": "0179067877",
#     "necoid": "190067877",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "BLDP",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:BLDP",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "025509137",
#     "other_ids": [],
# ...
#         "mic": "XSHE",
#         "context": "extractor",
#         "exchange_symbol": "Shenzhen:200028",
#         "exchange": "Shenzhen",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "009870940",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Shanghai Shyndec Pharmaceutical Co. Ltd.",
#     "id": "2122072075",
#     "necoid": "1895649",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "600420",
#         "mic": "XSHG",
#         "context": "extractor",
#         "exchange_symbol": "Shanghai:600420",
#         "exchange": "Shanghai",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "006532215",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "China Traditional Chinese Medicine Holdings Co. Ltd.",
#     "id": "1186750211",
#     "necoid": "1197750211",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "0570",
#         "mic": "XHKG",
#         "context": "extractor",
#         "exchange_symbol": "HongKong:0570",
#         "exchange": "HongKong",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "147406117",
#     "other_ids": [],
#     "ult_parent_id": "3956395594",
#     "name": "Chinese Academy of Engineering",
#     "id": "3541073697",
#     "necoid": "1415590066",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Applied Biosystems Intl. Inc.",
#     "id": "1669171615",
#     "necoid": "1680171615",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "016666123",
#     "other_ids": [],
#     "ult_parent_id": "3337654054",
#     "name": "Invitrogen Holdings Ltd.",
#     "id": "3117057219",
#     "necoid": "991573588",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "395948299",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Olink Holding AB (publ)",
#     "id": "5011417999",
#     "necoid": "8417999",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "084563238",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "China National Pharmaceutical Group Corp.",
#     "id": "0971564310",
#     "necoid": "982564310",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   }
# ]
# orion engineered carbons sa
# 200
# [
#   {
#     "orbis_id": "151500374",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Orion SA (Luxembourg)",
#     "id": "5011379672",
#     "necoid": "8379672",
#     "is_ult_parent": true,
#     "relevance": 0.9,
#     "securities": [
#       {
#         "symbol": "OEC",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:OEC",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# bunge
# 200
# [
#   {
#     "orbis_id": "538018261",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Producer AG",
#     "id": "5020250704",
#     "necoid": "758283442",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001791342",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Producer Ag LLC",
#     "id": "5020481699",
#     "necoid": "758514437",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000037685",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "CHS Inc.",
#     "id": "0396808862",
#     "necoid": "29972",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CHSCP",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:CHSCP",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "001630073",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Cargill Inc.",
#     "id": "2488338261",
#     "necoid": "3666502",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "027550407",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Arizona State University",
#     "id": "2827611636",
#     "necoid": "5181236",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006437887",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Ardent Mills LLC",
#     "id": "4026506501",
#     "necoid": "471682",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000002964",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Archer Daniels Midland Co.",
#     "id": "2412074279",
#     "necoid": "1758",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ADM",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:ADM",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000044279",
#     "other_ids": [],
#     "ult_parent_id": "1200642937",
#     "name": "Bunge North America Inc.",
#     "id": "2613624144",
#     "necoid": "488140513",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001736321",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "CGB Enterprises Inc.",
#     "id": "1105684681",
#     "necoid": "5602513",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000046470",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Conagra Brands Inc.",
#     "id": "2440049775",
#     "necoid": "314566144",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "CAG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:CAG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "226451996",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Continental Grain Co.",
#     "id": "2076204822",
#     "necoid": "2087204822",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "049964326",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "General Mills Inc.",
#     "id": "0514525578",
#     "necoid": "10598",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "GIS",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:GIS",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "221173677",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Mfa Inc.",
#     "id": "3335616221",
#     "necoid": "3345857",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000039347",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Riceland Foods Inc.",
#     "id": "3606163783",
#     "necoid": "2859686",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000760669",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Scoular Co.",
#     "id": "2393786766",
#     "necoid": "5299905",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000965595",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Andersons Inc.",
#     "id": "2804357403",
#     "necoid": "1479",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "ANDE",
#         "mic": "XNAS",
#         "context": "extractor",
#         "exchange_symbol": "NASDAQ-NMS:ANDE",
#         "exchange": "NASDAQ-NMS",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "008321833",
#     "other_ids": [],
#     "ult_parent_id": "2488338261",
#     "name": "Cargill",
#     "id": "2853602494",
#     "necoid": "728118863",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "160709894",
#     "other_ids": [],
#     "ult_parent_id": "1309279597",
#     "name": "US Department of Agriculture",
#     "id": "4053860838",
#     "necoid": "1928377207",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "327195303",
#     "other_ids": [],
#     "ult_parent_id": "2618230869",
#     "name": "Statistics Canada",
#     "id": "6000050715",
#     "necoid": "6050715",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "134739979",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "U.S. Grains Council",
#     "id": "1904074938",
#     "necoid": "1915074938",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "2412074279",
#     "name": "Adm Investor Services Inc.",
#     "id": "3711438792",
#     "necoid": "1585955161",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "049995802",
#     "other_ids": [],
#     "ult_parent_id": "1200642937",
#     "name": "Bunge Global SA",
#     "id": "3946763127",
#     "necoid": "255228",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "BG",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:BG",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "050599652",
#     "other_ids": [],
#     "ult_parent_id": "1932450020",
#     "name": "Food And Beverage Company Ltd.",
#     "id": "5020917645",
#     "necoid": "758950383",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "006739671",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Washington H. Soul Pattinson and Co. Ltd.",
#     "id": "1932450020",
#     "necoid": "28742",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "SOL",
#         "mic": "XASX",
#         "context": "extractor",
#         "exchange_symbol": "Australia:SOL",
#         "exchange": "Australia",
#         "type": "REFERENCE"
#       }
#     ]
#   },
#   {
#     "orbis_id": "006366014",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Personal Care",
#     "id": "5020491261",
#     "necoid": "758523999",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "036135757",
#     "other_ids": [],
#     "ult_parent_id": "2488338261",
#     "name": "Carval Investors LLC",
#     "id": "0812466651",
#     "necoid": "823466651",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "005439137",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Koninklijke DSM NV",
#     "id": "2953985778",
#     "necoid": "7910",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000003480",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Great Atlantic & Pacific Tea Co Inc.",
#     "id": "1565667100",
#     "necoid": "1576667100",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001656435",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Global Exports",
#     "id": "5020357527",
#     "necoid": "758390265",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000591053",
#     "other_ids": [],
#     "ult_parent_id": "1056752627",
#     "name": "Zen-Noh Grain Corp.",
#     "id": "1790111785",
#     "necoid": "5308024",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "051056661",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Itochu Corp.",
#     "id": "3587435415",
#     "necoid": "14035",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "8001",
#         "mic": "XTKS",
#         "context": "extractor",
#         "exchange_symbol": "Tokyo:8001",
#         "exchange": "Tokyo",
#         "type": "REFERENCE"
#       },
#       {
#         "symbol": "ITOCY",
#         "mic": "OTCM",
#         "context": "extractor",
#         "exchange_symbol": "OTC-PINK:ITOCY",
#         "exchange": "OTC-PINK",
#         "type": "SYNONYM"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000044345",
#     "other_ids": [],
#     "ult_parent_id": "3587435415",
#     "name": "Itochu Intl. Inc.",
#     "id": "4095527855",
#     "necoid": "2725067",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "003414975",
#     "other_ids": [],
#     "ult_parent_id": "2358467805",
#     "name": "Lactalis Intl.",
#     "id": "3842889624",
#     "necoid": "1717405993",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "198977941",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Edgard",
#     "id": "2736267677",
#     "necoid": "610784046",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "003921344",
#     "other_ids": [],
#     "ult_parent_id": "1870849235",
#     "name": "Louis Dreyfus & Co. Ltd.",
#     "id": "2175908085",
#     "necoid": "50424454",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "001634003",
#     "other_ids": [],
#     "ult_parent_id": "1870849235",
#     "name": "Louis Dreyfus Co. Holding Inc.",
#     "id": "3359325568",
#     "necoid": "5833834",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "018575292",
#     "other_ids": [],
#     "ult_parent_id": "1870849235",
#     "name": "Louis Dreyfus Co. B.V.",
#     "id": "3674930633",
#     "necoid": "1549447002",
#     "is_ult_parent": false,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "007306252",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Namoi Cotton Ltd.",
#     "id": "5010005804",
#     "necoid": "18131",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000472261",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "The Nature Conservancy",
#     "id": "1830203712",
#     "necoid": "3285536",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "State Technical College of Missouri",
#     "id": "0018014623",
#     "necoid": "5639351",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "058563513",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Skyland Grain LLC",
#     "id": "1544192562",
#     "necoid": "1555192562",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "000075691",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Topflight Grain Coop. Inc.",
#     "id": "0481178162",
#     "necoid": "5303158",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": []
#   },
#   {
#     "orbis_id": "003901521",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Tate & Lyle PLC",
#     "id": "2749697245",
#     "necoid": "26053",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "TATE",
#         "mic": "XLON",
#         "context": "extractor",
#         "exchange_symbol": "LSE:TATE",
#         "exchange": "LSE",
#         "type": "REFERENCE"
#       },
#       {
#         "symbol": "TATYY",
#         "mic": "OTCM",
#         "context": "extractor",
#         "exchange_symbol": "OTC-PINK:TATYY",
#         "exchange": "OTC-PINK",
#         "type": "SYNONYM"
#       }
#     ]
#   },
#   {
#     "orbis_id": "000315523",
#     "other_ids": [],
#     "ult_parent_id": "",
#     "name": "Norfolk Southern Corp.",
#     "id": "1830680297",
#     "necoid": "1841680297",
#     "is_ult_parent": true,
#     "relevance": 0.6,
#     "securities": [
#       {
#         "symbol": "NSC",
#         "mic": "XNYS",
#         "context": "extractor",
#         "exchange_symbol": "NYSE:NSC",
#         "exchange": "NYSE",
#         "type": "REFERENCE"
#       }
#     ]
#   }
# ]
# db_ticker
# db_name
# name
# orbis_id
# id
# symbol

# %%
df = pd.DataFrame(data)
df.to_csv(r'.\data\extracted correct symbol.csv')

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Divya\PycharmProjects\VQ Scraper
